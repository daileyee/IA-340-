# %% [markdown]
# # lab1

# %% [markdown]
# this is my first lab.

# %%
import pandas as pd 

covid_data = pd.read_csv("s3://ia-340-2025-fall-9874yay/data.csv")
covid_data.head()
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/fsspec/registry.py:298: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  14/12/2020   14     12  2020    746       6             Afghanistan    AF
# 1  13/12/2020   13     12  2020    298       9             Afghanistan    AF
# 2  12/12/2020   12     12  2020    113      11             Afghanistan    AF
# ...

# %%
collisions_data = pd.read_csv("s3://ia-340-2025-fall-9874yay/Motor_Vehicle_Collisions_-_Crashes.csv")
collisions_data.head()
# Out:
# /tmp/ipykernel_11177/3604102568.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   collisions_data = pd.read_csv("s3://ia-340-2025-fall-9874yay/Motor_Vehicle_Collisions_-_Crashes.csv")
#    CRASH DATE CRASH TIME   BOROUGH ZIP CODE  LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39       NaN      NaN       NaN        NaN
# 1  03/26/2022      11:45       NaN      NaN       NaN        NaN
# 2  11/01/2023       1:29  BROOKLYN  11230.0  40.62179 -73.970024
# 3  06/29/2022       6:55       NaN      NaN       NaN        NaN
# 4  09/21/2022      13:21       NaN      NaN       NaN        NaN
#
#                  LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0                     NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                     NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2  (40.62179, -73.970024)            OCEAN PARKWAY          AVENUE K
# ...
