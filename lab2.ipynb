# %%
import warnings
warnings.simplefilter('ignore')

import pandas as pd

df = pd.read_csv('s3://ia-340-2025-fall-9874yay/Telemedicine_Use_in_the_Last_4_Weeks.csv')
df.head()
# Out:
#                                            Indicator              Group  \
# 0  Adults Who Had Appointment with Health Profess...  National Estimate
# 1  Adults Who Had Appointment with Health Profess...             By Age
# 2  Adults Who Had Appointment with Health Profess...             By Age
# 3  Adults Who Had Appointment with Health Profess...             By Age
# 4  Adults Who Had Appointment with Health Profess...             By Age
#
#            State       Subgroup  Phase  Time Period      Time Period Label  \
# 0  United States  United States    3.1           28  Apr 14 - Apr 26, 2021
# 1  United States  18 - 29 years    3.1           28  Apr 14 - Apr 26, 2021
# 2  United States  30 - 39 years    3.1           28  Apr 14 - Apr 26, 2021
# 3  United States  40 - 49 years    3.1           28  Apr 14 - Apr 26, 2021
# 4  United States  50 - 59 years    3.1           28  Apr 14 - Apr 26, 2021
#
#   Time Period Start Date Time Period End Date  Value  Low CI  High CI  \
# ...

# %%
df.shape
# Out:
# (3344, 15)

# %%
df['Value']
# Out:
# 0       25.7
# 1       21.6
# 2       23.1
# 3       25.7
# 4       26.3
#         ...
# 3339    18.8
# 3340    18.9
# 3341     NaN
# 3342    13.8
# 3343    10.7
# Name: Value, Length: 3344, dtype: float64

# %%
df.sort_values(by='Time Period')
# Out:
#                                               Indicator  \
# 1942  Households With Children Where Any Child Had A...
# 1943  Households With Children Where Any Child Had A...
# 1948  Households With Children Where Any Child Had A...
# 1949  Households With Children Where Any Child Had A...
# 1950  Households With Children Where Any Child Had A...
# ...                                                 ...
# 3321  Households With Children Where Any Child Had A...
# 3322  Households With Children Where Any Child Had A...
# 3323  Households With Children Where Any Child Had A...
# 3276  Households With Children Where Any Child Had A...
# 3324  Households With Children Where Any Child Had A...
#
#                                                Group          State  \
# 1942         By Health insurance of adult respondent  United States
# 1943         By Health insurance of adult respondent  United States
# 1948                       By Total household income  United States
# ...

# %%
df[0:7]
# Out:
#                                            Indicator              Group  \
# 0  Adults Who Had Appointment with Health Profess...  National Estimate
# 1  Adults Who Had Appointment with Health Profess...             By Age
# 2  Adults Who Had Appointment with Health Profess...             By Age
# 3  Adults Who Had Appointment with Health Profess...             By Age
# 4  Adults Who Had Appointment with Health Profess...             By Age
# 5  Adults Who Had Appointment with Health Profess...             By Age
# 6  Adults Who Had Appointment with Health Profess...             By Age
#
#            State       Subgroup  Phase  Time Period      Time Period Label  \
# 0  United States  United States    3.1           28  Apr 14 - Apr 26, 2021
# 1  United States  18 - 29 years    3.1           28  Apr 14 - Apr 26, 2021
# 2  United States  30 - 39 years    3.1           28  Apr 14 - Apr 26, 2021
# 3  United States  40 - 49 years    3.1           28  Apr 14 - Apr 26, 2021
# ...

# %%
df[df['Time Period'] > 28]
# Out:
#                                                                 Indicator  \
# Time Period Start Date
# 04/28/2021              Adults Who Had Appointment with Health Profess...
# 04/28/2021              Adults Who Had Appointment with Health Profess...
# 04/28/2021              Adults Who Had Appointment with Health Profess...
# 04/28/2021              Adults Who Had Appointment with Health Profess...
# 04/28/2021              Adults Who Had Appointment with Health Profess...
# ...                                                                   ...
# 07/27/2022              Households With Children Where Any Child Had A...
# 07/27/2022              Households With Children Where Any Child Had A...
# 07/27/2022              Households With Children Where Any Child Had A...
# 07/27/2022              Households With Children Where Any Child Had A...
# 07/27/2022              Households With Children Where Any Child Had A...
#
# ...

# %%
df.set_index('Time Period Start Date',inplace=True) 
df.head()
# Out:
#                                                                 Indicator  \
# Time Period Start Date
# 04/14/2021              Adults Who Had Appointment with Health Profess...
# 04/14/2021              Adults Who Had Appointment with Health Profess...
# 04/14/2021              Adults Who Had Appointment with Health Profess...
# 04/14/2021              Adults Who Had Appointment with Health Profess...
# 04/14/2021              Adults Who Had Appointment with Health Profess...
#
#                                     Group          State       Subgroup  \
# Time Period Start Date
# 04/14/2021              National Estimate  United States  United States
# 04/14/2021                         By Age  United States  18 - 29 years
# 04/14/2021                         By Age  United States  30 - 39 years
# 04/14/2021                         By Age  United States  40 - 49 years
# 04/14/2021                         By Age  United States  50 - 59 years
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3344 entries, 04/14/2021 to 07/27/2022
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Indicator             3344 non-null   object
#  1   Group                 3344 non-null   object
#  2   State                 3344 non-null   object
#  3   Subgroup              3344 non-null   object
#  4   Phase                 3344 non-null   float64
#  5   Time Period           3344 non-null   int64
#  6   Time Period Label     3344 non-null   object
#  7   Time Period End Date  3344 non-null   object
#  8   Value                 3104 non-null   float64
#  9   Low CI                3104 non-null   float64
#  10  High CI               3104 non-null   float64
#  11  Confidence Interval   3104 non-null   object
#  12  Quartile Range        2142 non-null   object
#  13  Suppression Flag      52 non-null     float64
# dtypes: float64(5), int64(1), object(8)
# ...

# %%
df.describe()
# Out:
#              Phase  Time Period        Value       Low CI      High CI  \
# count  3344.000000  3344.000000  3104.000000  3104.000000  3104.000000
# mean      3.019498    36.000598    19.605638    15.760374    24.118814
# std       0.990528    10.361604     5.368918     5.482188     5.889849
# min      -1.000000     1.000000     6.800000     3.800000    10.800000
# 25%       3.100000    32.000000    15.800000    11.900000    19.900000
# 50%       3.200000    37.500000    19.250000    15.400000    23.500000
# 75%       3.400000    43.000000    23.000000    19.700000    27.500000
# max       3.500000    48.000000    44.900000    39.200000    57.400000
#
#        Suppression Flag
# count              52.0
# mean                1.0
# std                 0.0
# min                 1.0
# 25%                 1.0
# 50%                 1.0
# 75%                 1.0
# max                 1.0

# %%
df = df.rename(columns={"Time Period Start Date": "Start Date", "Time Period End Date": "End Date"}) 
df.head()
# Out:
#                                                                 Indicator  \
# Time Period Start Date
# 04/14/2021              Adults Who Had Appointment with Health Profess...
# 04/14/2021              Adults Who Had Appointment with Health Profess...
# 04/14/2021              Adults Who Had Appointment with Health Profess...
# 04/14/2021              Adults Who Had Appointment with Health Profess...
# 04/14/2021              Adults Who Had Appointment with Health Profess...
#
#                                     Group          State       Subgroup  \
# Time Period Start Date
# 04/14/2021              National Estimate  United States  United States
# 04/14/2021                         By Age  United States  18 - 29 years
# 04/14/2021                         By Age  United States  30 - 39 years
# 04/14/2021                         By Age  United States  40 - 49 years
# 04/14/2021                         By Age  United States  50 - 59 years
#
# ...

# %%
df.isnull().sum()
# Out:
# Indicator                 0
# Group                     0
# State                     0
# Subgroup                  0
# Phase                     0
# Time Period               0
# Time Period Label         0
# End Date                  0
# Value                   240
# Low CI                  240
# High CI                 240
# Confidence Interval     240
# Quartile Range         1202
# Suppression Flag       3292
# dtype: int64

# %% [markdown]
# A) My dataset has 3344 rows, and 15 columns. There is a combination of numeric and text columns. My initial impression is the data is initially sorted by "Indicator", where they are either labled as "Adults Who Had Appointment with Health Professional Over Video or Phone, Last 4 Weeks" or "Households With Children Where Any Child Had Appointment with Health Professional Over Video or Phone, Last 4 Weeks".
#
# B) I renamed the "Time Period Start Date" and "Time Period End Date" columns and shortend them to just "Start Date" and "End Date". There were 5454 missing values, but I did not drop them in order to avoid getting rid of entire rows.
#
# C) I selected the "Value" column and then sorted by "Time Period". The output indicates that the highest value was 25.7 and the lowest was 10.7. It also shows that the time period for the survey ranged from 1 to 48 days.

# %%
sum_cases_by_group = df.groupby('Group')['Time Period'].sum()
sum_cases_by_group.head()
# Out:
# Group
# By Age                                                                                5614
# By Current US Armed Forces or National Guard service of adult respondent or spouse    1604
# By Disability status                                                                  1604
# By Education                                                                          3208
# By Education of adult respondent                                                      2406
# Name: Time Period, dtype: int64

# %%
sum_cases_by_date.plot.bar()
# Out:
# <Axes: xlabel='Group'>

# %% [markdown]
# This bar chart shows the distribution of groups studied by time period. This indicates which groups had the largest amount of days under observation. Therefore, we can see that most of the data studied were sorted by state, with total household income being the second greatest.

# %%
df.hist(layout=(6,6), figsize=(10, 5), sharey=False, sharex=False, bins=50)
# Out:
# array([[<Axes: title={'center': 'Phase'}>,
#         <Axes: title={'center': 'Time Period'}>,
#         <Axes: title={'center': 'Value'}>,
#         <Axes: title={'center': 'Low CI'}>,
#         <Axes: title={'center': 'High CI'}>,
#         <Axes: title={'center': 'Suppression Flag'}>],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# These histograms indicate the distribution of each of the quantitative metrics studied. The "Value" data is normally distributed and the "Low CI" and "High CI" data are both slightly skewed.
